# %% [markdown]
# # GCNII - Results

# %% [markdown]
# # How to
#
# Upload GDL_Project.zip

# %%
# Unzip and extract files from folder to current directory
# !unzip GDL_Project.zip > null
# !mv GDL_Project/3_*/* .
# !rm -r GDL_P* __MACOSX > null

# %%
# Install spektral & tensorflow addons
# !pip3 install spektral > null
# !pip install tensorflow-addons > null

# %% [markdown]
# ## 1/4 Cornell (CPU)

# %%
# !python3 train_cornell.py   # CPU
# Out:
# 2022-06-06 01:48:53.193990: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/1500
# 1/1 [==============================] - 3s 3s/step - loss: 1.7296 - acc: 0.2844 - val_loss: 1.2230 - val_acc: 0.5676
# Epoch 2/1500
# 1/1 [==============================] - 0s 37ms/step - loss: 1.2752 - acc: 0.5138 - val_loss: 1.1695 - val_acc: 0.6216
# Epoch 3/1500
# 1/1 [==============================] - 0s 34ms/step - loss: 1.3266 - acc: 0.5321 - val_loss: 1.1747 - val_acc: 0.5676
# Epoch 4/1500
# 1/1 [==============================] - 0s 34ms/step - loss: 1.2175 - acc: 0.5321 - val_loss: 1.0814 - val_acc: 0.6216
# Epoch 5/1500
# 1/1 [==============================] - 0s 34ms/step - loss: 1.1817 - acc: 0.5413 - val_loss: 1.1256 - val_acc: 0.5946
# Epoch 6/1500
# 1/1 [==============================] - 0s 33ms/step - loss: 1.1843 - acc: 0.5229 - val_loss: 1.1352 - val_acc: 0.5946
# Epoch 7/1500
# ...

# %% [markdown]
# ## 2/4 Texas (CPU)

# %%
# !python3 train_texas.py   # CPU
# Out:
# 2022-06-06 01:49:10.996611: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/1500
# 1/1 [==============================] - 5s 5s/step - loss: 1.6321 - acc: 0.3028 - val_loss: 1.6999 - val_acc: 0.3514
# Epoch 2/1500
# 1/1 [==============================] - 0s 46ms/step - loss: 1.6442 - acc: 0.2110 - val_loss: 1.5827 - val_acc: 0.2973
# Epoch 3/1500
# 1/1 [==============================] - 0s 41ms/step - loss: 1.6368 - acc: 0.2661 - val_loss: 1.5896 - val_acc: 0.2162
# Epoch 4/1500
# 1/1 [==============================] - 0s 43ms/step - loss: 1.5581 - acc: 0.3578 - val_loss: 1.5931 - val_acc: 0.3243
# Epoch 5/1500
# 1/1 [==============================] - 0s 51ms/step - loss: 1.6076 - acc: 0.3028 - val_loss: 1.5689 - val_acc: 0.3514
# Epoch 6/1500
# 1/1 [==============================] - 0s 46ms/step - loss: 1.7741 - acc: 0.4037 - val_loss: 1.5610 - val_acc: 0.4324
# Epoch 7/1500
# ...

# %% [markdown]
# ## 3/4 Wisconsin (CPU)

# %%
# !python3 train_wisconsin.py   # CPU
# Out:
# 2022-06-06 01:50:00.994566: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/1500
# 1/1 [==============================] - 3s 3s/step - loss: 1.6211 - acc: 0.2467 - val_loss: 1.7197 - val_acc: 0.2000
# Epoch 2/1500
# 1/1 [==============================] - 0s 56ms/step - loss: 1.5290 - acc: 0.4333 - val_loss: 1.5206 - val_acc: 0.3800
# Epoch 3/1500
# 1/1 [==============================] - 0s 54ms/step - loss: 1.5260 - acc: 0.4867 - val_loss: 1.5433 - val_acc: 0.3600
# Epoch 4/1500
# 1/1 [==============================] - 0s 48ms/step - loss: 1.4636 - acc: 0.5333 - val_loss: 1.5397 - val_acc: 0.4200
# Epoch 5/1500
# 1/1 [==============================] - 0s 48ms/step - loss: 1.4251 - acc: 0.5467 - val_loss: 1.5478 - val_acc: 0.3800
# Epoch 6/1500
# 1/1 [==============================] - 0s 58ms/step - loss: 1.3492 - acc: 0.5867 - val_loss: 1.4855 - val_acc: 0.4000
# Epoch 7/1500
# ...

# %% [markdown]
# ## 4/4 Pubmed (GPU)

# %%
# !python3 train_pubmed.py    # GPU
# Out:
# tcmalloc: large alloc 3110084608 bytes == 0xdbe8000 @  0x7f86d1033001 0x7f86ce2af1af 0x7f86ce305c23 0x7f86ce306a87 0x7f86ce3a8823 0x5936cc 0x548c51 0x5127f1 0x593dd7 0x548ae9 0x51566f 0x549576 0x593fce 0x548ae9 0x5127f1 0x549576 0x593fce 0x548ae9 0x51566f 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f86d0c2ec87 0x5b621a
# tcmalloc: large alloc 3110084608 bytes == 0xc71ea000 @  0x7f86d10311e7 0x7f86ce2af0ce 0x7f86ce309726 0x7f86ce309b09 0x7f86ce30b620 0x7f86ce30bd1b 0x7f86ce3ac333 0x5936cc 0x548c51 0x51566f 0x549576 0x604173 0x5f5506 0x5f8c6c 0x5f9206 0x64faf2 0x64fc4e 0x7f86d0c2ec87 0x5b621a
# 2022-06-06 00:37:14.744880: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# Epoch 1/1500
# 1/1 [==============================] - 20s 20s/step - loss: 1.0976 - acc: 0.4167 - val_loss: 1.0987 - val_acc: 0.4000
# Epoch 2/1500
# ...
